# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *

# %%
def fitness_func(indiv): return (indiv.data**2).sum()

population = Population.new_random()
opt = Optimization(population, fitness_func)
opt
# Out:
# Optimization(population=Population(n=20, dimension=10), get_fitness=<function fitness_func at 0x7f41703f2510>, get_constraints=[], constraint_params=None, CR=0.3, betamin=0.2, betamax=0.8, max_evals=None, metrics=('fitness',), callbacks=[<denn.callbacks.Recorder object at 0x7f41460ed9b0>])

# %%
opt.run(100)

# %%
opt.recorder.plot()

# %%
opt.best
# Out:
# Individual(dimensions=10, lower_limit=-5, upper_limit=5, idx=9, gen=99, fitness_value=21.05156328625887, constraints=None, constraints_sum=None, is_feasible=False)
