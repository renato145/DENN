# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *

# %%
path = Path('../../data/large')

# %%
ab = pd.read_csv(path/'dC_01.csv', header=None).values[0]
bestKnow = pd.read_csv(path/'Best_Know1Fxs.csv', header=None).values[0]
bestKnow = bestKnow[:100].astype(float)
java_results = pd.read_csv(path/'Feasibility1Fs.csv', header=None).values[0]
java_results = java_results[:-1].astype(float)
java_results_all = pd.read_csv(path/'Feasibility1Fs.csv', header=None).iloc[:,:-1]

# %%
D = 30
frequency = 1_000
max_times = len(ab)
total_generations = max_times * frequency + 1000

def fitness_func(indiv, b, t): return (indiv.data**2).sum()
def constraint_func(indiv, b, t): return -b[t] + sum((1/np.sqrt(D))*indiv.data)

population = Population.new_random(dimension=D)
opt = Optimization(population, fitness_func, constraint_func, constraint_params=[ab],
                   max_times=max_times, frequency=frequency, callbacks=[OnChangeRestartPopulation])
opt.state_dict
# Out:
# {'gen': 0, 'evals': 0, 'time': 0, 'best': None}

# %%
opt.run(total_generations)
# Out:
# A proper report should be shown here :)
# Total time: 00:13

# %%
df = pd.DataFrame({'java':java_results, 'bestKnow':bestKnow[:-1], 'results': opt.recorder.best_times_fitness[:-1]})
# df = pd.DataFrame({'java':java_results, 'bestKnow':bestKnow[:-1], 'results': opt.recorder.best_times_fitness[:-1],
#                    'results2': [e.fitness_value for e in opt.recorder.best_times2[:-1]]})

# %%
df.plot(figsize=(12,5))

# %%
plt.plot([e.constraints_sum for e in opt.recorder.best_times])

# %% [markdown]
# # Multiple runs

# %%
runs = (Optimization(population, fitness_func, constraint_func, constraint_params=[ab],
                     max_times=max_times, frequency=frequency, callbacks=[DynamicConstraint,OnChangeRestartPopulation])
        .create_multiple_runs(n_runs=20))

# %%
runs.run(total_generations)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='20', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20/20 00:50<00:00]
#     </div>
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Run cancelled: `max_time` reached.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Run cancelled: `max_time` reached.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Run cancelled: `max_time` reached.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Run cancelled: `max_time` reached.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='101000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.
# Run cancelled: `max_time` reached.

# %%
runs.times_data
# Out:
#          run_1      run_2       run_3      run_4       run_5      run_6  \
# 0   100.038801  60.379284  110.421294  99.977745   97.082758  90.919458
# 1   100.038801  60.379284  110.421294  99.977745  391.760223  90.919458
# 2   100.038801  60.379284  110.421294  99.977745  391.760223  90.919458
# 3   100.038801  60.379284  110.421294  99.977745  391.760223  90.919458
# 88  58.366773   63.952289  54.702000   69.309421  56.989692   63.178210
# 89  58.366773   63.952289  54.702000   69.309421  56.989692   63.178210
# 90  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 91  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 92  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 93  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 94  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 95  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 96  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 97  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 98  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
# 99  58.366773   63.952289  54.702000   60.994569  56.989692   63.178210
#
#         run_19     run_20
# 0   111.670869  90.810040
# 1   111.670869  90.810040
# 2   111.670869  90.810040
# 3   111.670869  90.810040
# 4   111.670869  90.810040
# 5   111.670869  90.810040
# 6   111.670869  90.810040
# 7   111.670869  90.810040
# 8    66.910740  78.439100
# 9   108.526506  78.439100
# 10  121.069746  78.439100
# 11  106.382115  78.439100
# 12  103.523872  75.694873
# 13  103.523872  75.694873
# 14  103.523872  75.694873
# 15  103.523872  75.694873
# 16   99.523135  75.694873
# 17  258.296324  75.694873
# 18  135.654973  75.694873
# 19  105.179864  75.694873
# 20  147.128714  75.694873
# 21   79.029548  75.694873
# 22   79.029548  75.694873
# 23   79.029548  75.694873
# 24   76.373683  75.694873
# 25   76.373683  75.694873
# 26   56.785045  55.716407
# 27   56.785045  55.716407
# 28   56.785045  55.716407
# 29   56.785045  55.716407
# ..         ...        ...
# 70   56.785045  55.716407
# 71   56.785045  55.716407
# 72   56.785045  55.716407
# 73   56.785045  55.716407
# 74   56.785045  55.716407
# 75   56.785045  55.716407
# 76   56.785045  55.716407
# 77   56.785045  55.716407
# 78   56.785045  55.716407
# 79   56.785045  55.716407
# 80   56.785045  55.716407
# 81   56.785045  55.716407
# 82   56.785045  55.716407
# 83   56.785045  55.716407
# 84   56.785045  55.716407
# 85   56.785045  55.716407
# 86   56.785045  55.716407
# 87   56.785045  55.716407
# 88   56.785045  55.716407
# 89   56.785045  55.716407
# 90   56.785045  55.716407
# 91   56.785045  55.716407
# 92   56.785045  55.716407
# 93   56.785045  55.716407
# 94   56.785045  55.716407
# 95   56.785045  55.716407
# 96   56.785045  55.716407
# 97   56.785045  55.716407
# 98   56.785045  55.716407
# 99   56.785045  55.716407
#
# [100 rows x 20 columns]

# %%
runs.times_data.plot();

# %%
plt.figure(figsize=(14,6))
plt.plot(bestKnow, '-', label='best_know')
plt.plot(java_results, '-', label='java')
for i,opt in enumerate(runs.optimizations):
    plt.plot(opt.recorder.best_times_fitness, '-', label=f'result {i}')
plt.legend();

# %% [markdown]
# # --
