# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *

# %%
d = GroupData.from_query(freq=10)
d
# Out:
# No metric file for: 'nn_errors'
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# GroupData(
#   freq=10
#   query params=['experiment', 'function', 'div']
# ) [120 elements]

# %%
d.plot_metric(col='experiment', row='function', figsize=(14,10))
plt.tight_layout()
# Out:
# Select one:
# (0) fitness
# (1) nfe
# (2) sr
# (3) mof
# (4) sumcv
# (5) arr
# (6) nn_errors
# 0

# %%
t = d[0]

# %%
df = t.read_metric('nn_errors')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-5145a684dcb1> in <module>
# ----> 1 df = t.read_metric('nn_errors')
#
# ~/Essensial/github/DENN/denn/explore.py in read_metric(self, metric)
#      93         assert metric in MetricsFiles, f'Invalid metric: {metric!r}\nAvailable ones are: {MetricsFiles}'
#      94         files = [o for o in self.path.ls() if metric in o.name]
# ---> 95         assert len(files)==1, f'More files than expected check:\n{files}'
#      96         return pd.read_csv(files[0])
#      97
#
# AssertionError: More files than expected check:
# []

# %%
t.plot_metric('nn_errors')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-ddd268ceae01> in <module>
# ----> 1 t.plot_metric('nn_errors')
#
# ~/Essensial/github/DENN/denn/explore.py in plot_metric(self, metric, ax, figsize, **kwargs)
#     105     def plot_metric(self, metric:Optional[str]=None, ax:Optional[plt.Axes]=None, figsize:tuple=(6,4), **kwargs:Any)->plt.Axes:
#     106         if ax is None: fig,ax = plt.subplots(figsize=figsize)
# --> 107         df = self.read_metric(metric)
#     108         have_time = metric_have_time(df)
#     109         if have_time: self._plot_time_metric(df, ax, **kwargs)
#
# ~/Essensial/github/DENN/denn/explore.py in read_metric(self, metric)
#      93         assert metric in MetricsFiles, f'Invalid metric: {metric!r}\nAvailable ones are: {MetricsFiles}'
#      94         files = [o for o in self.path.ls() if metric in o.name]
# ...

# %%
t = ExperimentData('exp1', 'sphere', False, freq=4, div='HMu')

# %%
t.params
# Out:
# {'experiment': 'exp1',
#  'function': 'sphere',
#  'isnn': False,
#  'freq': 4,
#  'div': 'HMu'}

# %%
ExperimentData('exp1', 'sphere', True, freq=4, nn_p=3, div='HMu')
