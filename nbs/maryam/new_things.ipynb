# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *

# %%
d = GroupData.from_query(freq=10)
d
# Out:
# GroupData(
#   freq=10
#   query params=['experiment', 'function', 'div']
# ) [108 elements]

# %%
d.plot_metric(row='experiment', col='function', figsize=(14,10))
plt.tight_layout()
# Out:
# Select one:
# (0) fitness
# (1) nfe
# (2) sr
# (3) mof
# (4) sumcv
# (5) arr
# (6) nn_errors
# 0

# %%
t = d[0]

# %%
df = t.read_metric('nn_errors')

# %%
t.plot_metric('nn_errors')

# %%
t = ExperimentData('exp1', 'sphere', False, freq=4, div='HMu')

# %%
t.params
# Out:
# {'experiment': 'exp1',
#  'function': 'sphere',
#  'isnn': False,
#  'freq': 4,
#  'div': 'HMu'}

# %%
ExperimentData('exp1', 'sphere', True, freq=4, nn_p=3, div='HMu')
# Out:
# ExperimentData(
#   experiment=exp1
#   function=sphere
#   isnn=True
#   freq=4
#   nn_p=3
#   div=HMu
#   path=../../data/cluster_results/exp1/sphere/nn/freq4nn_w5nn_p3nn_s3nn_tw5nn_bs4nn_epoch3divHMu
# )
