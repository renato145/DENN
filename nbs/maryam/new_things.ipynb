# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *

# %%
d = GroupData(experiment='exp2')
# Out:
# Too many files for metric: 'fitness'
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNN_fitness.csv
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNNRestart_fitness.csv
# Too many files for metric: 'nfe'
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNN_nfe.csv
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNNRestart_nfe.csv
# Too many files for metric: 'sr'
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNN_sr.csv
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNNRestart_sr.csv
# Too many files for metric: 'mof'
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNNRestart_mof.csv
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNN_mof.csv
# Too many files for metric: 'sumcv'
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNNRestart_sumcv.csv
# ../../data/cluster_results/exp2/sphere/nonn/freq0.5divNo/noNN_sumcv.csv
# Too many files for metric: 'arr'
# ...
