# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *
import pandas as pd
import seaborn as sns
import io #Used as buffer

# %% [markdown]
# # Functions

# %%
path= Path(f'../../data/cluster_results')
col_by_freq = True
col_palette = 'Set3'
pat = re.compile('.*/(exp\d)/(\w*)/nonn/freq([0-9\.]+)div(\w+)/(\w+)_\w+.csv')
decode_keys = ['experiment','function','freq','div','method']
nn_pat = re.compile('.*/(exp\d)/(\w*)/nn/freq([0-9\.]+)\w+div([A-Za-z]+)/(\w+)_(\w+)_\w+.csv')
nn_decode_keys = ['experiment','function','freq','div','method','replace_mech']

def get_files(m): return list(path.glob(f'**/nonn/**/*{m}.csv'))
def get_nn_files(m): return list(path.glob(f'**/nn/**/*{m}.csv'))

def read_csv(f,m):
    df = pd.read_csv(f)
    for k,v in zip(decode_keys,pat.search(str(f)).groups()): df[k] = v
    df['freq'] = df['freq'].astype(float)
    df['method'] = df['method'] + '_' + df['div']
#     df['method'] = df['method'].str.replace('noNNRestart', 'noNN_Rst')
    df['method'] = df['method'].str.replace('noNNRestart_No', 'noNN_Rst')
    df.drop('div', axis=1, inplace=True)
    df.rename({'0':m.upper(), m:m.upper()}, axis=1, inplace=True)
    return df

def read_nn_csv(f,m):
    df = pd.read_csv(f)
    for k,v in zip(nn_decode_keys,nn_pat.search(str(f)).groups()): df[k] = v
    df['freq'] = df['freq'].astype(float)
    df['method'] = df['method'] + '_' + df['replace_mech'] + '_' + df['div']
    df['method'] = df['method'].str.replace('NNnorm_Worst', 'NN')
    df.drop(['replace_mech','div'], axis=1, inplace=True)
    df.rename({'0':m.upper(), m:m.upper()}, axis=1, inplace=True)
    return df

def get_data(m, normalize=False):
    files = get_files(m)
    nn_files = get_nn_files(m)
    data = pd.concat([read_csv(f,m) for f in files] + [read_nn_csv(f,m) for f in nn_files])
    if normalize:
        data_norm = (data.groupby(['experiment','function','freq','method'])[m.upper()].mean().reset_index()
                         .groupby(['experiment','function'])[m.upper()].min().reset_index()
                         .rename({m.upper():m.upper()+'_norm'}, axis=1))
        data = data.merge(data_norm, 'left')
        data[m.upper()+'_norm'] = data[m.upper()] / data[m.upper()+'_norm']
    return data.reset_index(drop=True)
    return data

def plot_one(data, m, normalize=False, title='', title_size=14, col_by_freq=col_by_freq, col_palette=col_palette,
             legend=False, hide_x=True, hide_y=True, ax=None, do_lim=True, ll=0.2, ul=0.8):
    m = m.upper()
    if normalize: m = m + '_norm' 
    if ax is None: fig,ax = plt.subplots(1,1,figsize=(6,4))
    sns.boxplot('method' if col_by_freq else 'freq', m, hue='freq' if col_by_freq else 'method',
                data=data, palette=col_palette,
                # width=2.5,
                linewidth=0.5, fliersize=0, ax=ax)
    if not legend: ax.get_legend().remove()
    if do_lim:
        ax.set_ylim(-0.05,1.05)
    else:
        g = data.groupby(['method','freq'])[m]
        q1,q3 = g.quantile(ll),g.quantile(ul)
        iqr = q3-q1
        lower_lim = (q1 - 1.5*iqr).min()
        upper_lim = (q3 + 1.5*iqr).max()
        lower_lim = data[m][data[m]>=lower_lim].min()
        upper_lim = data[m][data[m]<=upper_lim].max()
        ax.set_ylim(lower_lim,upper_lim)
        
    ax.set_xlabel('')
    if hide_x: ax.set_xticklabels([])
    if hide_y: ax.set_ylabel('')
    ax.set_title(title, size=title_size)
    return ax

def plot_all_vertical(m, normalize=False, title_size=14, col_by_freq=col_by_freq, col_palette=col_palette, do_lim=True,
                      ll=0.2, ul=0.8):
    data = get_data(m, normalize=normalize)
#     fig,axss = plt.subplots(4, 3, figsize=(14,16), sharex=do_lim, sharey=do_lim)
    fig,axss = plt.subplots(4, 3, figsize=(26,18), sharex=False, sharey=False)
    for i,(axs,exp) in enumerate(zip(axss,['exp1','exp2','exp3','exp4'])):
        first_exp = i==0
        for j,(ax,func) in enumerate(zip(axs,['sphere', 'rosenbrock', 'rastrigin'])):
            first_func = j==0
            test = data.query(f'experiment=={exp!r} and function=={func!r}').sort_values('method', ascending=False)
            plot_one(test, m, normalize=normalize, title=f'{exp}-{func.title()}', title_size=title_size, hide_x=False,
                     hide_y=not first_func, col_by_freq=col_by_freq, col_palette=col_palette, ax=ax,
                     do_lim=do_lim, ll=ll, ul=ul)
        ax.legend(loc='upper left', ncol=3)
    plt.tight_layout()
    return fig,axss

def plot_all_horizontal(m, normalize=False, title_size=14, col_by_freq=col_by_freq, col_palette=col_palette, do_lim=True,
                        ll=0.2, ul=0.8):
    data = get_data(m, normalize=normalize)
#     fig,axss = plt.subplots(4, 3, figsize=(14,16), sharex=do_lim, sharey=do_lim)
    fig,axss = plt.subplots(3, 4, figsize=(28,20), sharex=False, sharey=False)#20,12
    for i,exp in enumerate(['exp1','exp2','exp3','exp4']):#
        first_exp = i==0
        axs = axss[:,i]
        for j,(ax,func) in enumerate(zip(axs,['sphere', 'rosenbrock', 'rastrigin'])):
            first_func = i==0
            test = data.query(f'experiment=={exp!r} and function=={func!r}').sort_values('method', ascending=False)
            plot_one(test, m, normalize=normalize, title=f'{exp}-{func.title()}', title_size=title_size, hide_x=False,
                     hide_y=not first_func, col_by_freq=col_by_freq, col_palette=col_palette, ax=ax,
                     do_lim=do_lim, ll=ll, ul=ul)
        
    for axs in axss: axs[-1].legend(loc='upper right', ncol=3)
    plt.tight_layout()
    return fig,axss

# %% [markdown]
# # Plots

# %%
labels_order = ['noNN_RI', 'noNN_HMu', 'noNN_CwN', 'noNN_No', 'noNN_Rst', 'NN_RI',
                'NN_HMu', 'NN_CwN', 'NN_No']

# %%
def get_heatmap_data(m):
    df = get_data(m)
    df.function = df.function.str.title()
    m = m.upper()
    df_pivot = df.pivot_table(index=['experiment','function','freq'], columns=['method'], values=[m])[m]
    return df_pivot

# %%
df_pivot = get_heatmap_data('arr')[labels_order]
df_pivot_rank = df_pivot.rank(axis=1, ascending=False)

# %%
df_pivot_rank.style.background_gradient(cmap=plt.cm.Greens, axis=1)
# Out:
# <style  type="text/css" >
#     #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col0 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col2 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col3 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col5 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col6 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col7 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row0_col8 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col1 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col2 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col4 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col5 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col6 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col7 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row1_col8 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col0 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col2 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col3 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col5 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col6 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col7 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row2_col8 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col0 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col1 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col2 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col5 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col6 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col7 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row3_col8 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col0 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col1 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col2 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col5 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col6 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col7 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row4_col8 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col0 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col1 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col2 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col5 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col6 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col7 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row5_col8 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row6_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row6_col1 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row6_col2 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row6_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row6_col4 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_12c5acec_3f4a_11ea_933d_f40f24125f08row6_col5 {
#             background-color:  #73c476;
#             color:  #000000;

# %%
summary = df_pivot_rank.groupby(['experiment']).mean() #,'function'

summary.round(2).style.background_gradient(cmap=plt.cm.Greens, axis=1)
# Out:
# <style  type="text/css" >
#     #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col0 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col1 {
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col2 {
#             background-color:  #2a924a;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col5 {
#             background-color:  #bae3b3;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col6 {
#             background-color:  #88ce87;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col7 {
#             background-color:  #349d53;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col8 {
#             background-color:  #a8dca2;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col0 {
#             background-color:  #e0f3db;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col1 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col3 {
#             background-color:  #65bd6f;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col5 {
#             background-color:  #53b466;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col6 {
#             background-color:  #6bc072;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col7 {
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col8 {
#             background-color:  #b2e0ac;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col0 {
#             background-color:  #c9eac2;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col1 {
#             background-color:  #abdda5;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col3 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col5 {
#             background-color:  #94d390;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col6 {
#             background-color:  #68be70;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col7 {
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row2_col8 {
#             background-color:  #45ad5f;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col0 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col1 {
#             background-color:  #50b264;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col3 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col5 {
#             background-color:  #c0e6b9;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col6 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col7 {
#             background-color:  #087432;
#             color:  #f1f1f1;
#         }    #T_12d56c04_3f4a_11ea_933d_f40f24125f08row3_col8 {
#             background-color:  #7ac77b;
#             color:  #000000;
#         }</style><table id="T_12d56c04_3f4a_11ea_933d_f40f24125f08" ><thead>    <tr>        <th class="index_name level0" >method</th>        <th class="col_heading level0 col0" >noNN_RI</th>        <th class="col_heading level0 col1" >noNN_HMu</th>        <th class="col_heading level0 col2" >noNN_CwN</th>        <th class="col_heading level0 col3" >noNN_No</th>        <th class="col_heading level0 col4" >noNN_Rst</th>        <th class="col_heading level0 col5" >NN_RI</th>        <th class="col_heading level0 col6" >NN_HMu</th>        <th class="col_heading level0 col7" >NN_CwN</th>        <th class="col_heading level0 col8" >NN_No</th>    </tr>    <tr>        <th class="index_name level0" >experiment</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12d56c04_3f4a_11ea_933d_f40f24125f08level0_row0" class="row_heading level0 row0" >exp1</th>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col0" class="data row0 col0" >1.89</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col1" class="data row0 col1" >8.22</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col2" class="data row0 col2" >6.67</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col3" class="data row0 col3" >8.78</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col4" class="data row0 col4" >1.22</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col5" class="data row0 col5" >3.44</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col6" class="data row0 col6" >4.56</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col7" class="data row0 col7" >6.33</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row0_col8" class="data row0 col8" >3.89</td>
#             </tr>
#             <tr>
#                         <th id="T_12d56c04_3f4a_11ea_933d_f40f24125f08level0_row1" class="row_heading level0 row1" >exp2</th>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col0" class="data row1 col0" >2.44</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col1" class="data row1 col1" >4.22</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col2" class="data row1 col2" >9</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col3" class="data row1 col3" >5.44</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col4" class="data row1 col4" >1.33</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col5" class="data row1 col5" >5.78</td>
#                         <td id="T_12d56c04_3f4a_11ea_933d_f40f24125f08row1_col6" class="data row1 col6" >5.33</td>

# %%
summary.round(2).style.highlight_min(axis=1)
# Out:
# <style  type="text/css" >
#     #T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col4 {
#             background-color:  yellow;
#         }    #T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col4 {
#             background-color:  yellow;
#         }    #T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col4 {
#             background-color:  yellow;
#         }    #T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col4 {
#             background-color:  yellow;
#         }</style><table id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08" ><thead>    <tr>        <th class="index_name level0" >method</th>        <th class="col_heading level0 col0" >noNN_RI</th>        <th class="col_heading level0 col1" >noNN_HMu</th>        <th class="col_heading level0 col2" >noNN_CwN</th>        <th class="col_heading level0 col3" >noNN_No</th>        <th class="col_heading level0 col4" >noNN_Rst</th>        <th class="col_heading level0 col5" >NN_RI</th>        <th class="col_heading level0 col6" >NN_HMu</th>        <th class="col_heading level0 col7" >NN_CwN</th>        <th class="col_heading level0 col8" >NN_No</th>    </tr>    <tr>        <th class="index_name level0" >experiment</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08level0_row0" class="row_heading level0 row0" >exp1</th>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col0" class="data row0 col0" >1.89</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col1" class="data row0 col1" >8.22</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col2" class="data row0 col2" >6.67</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col3" class="data row0 col3" >8.78</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col4" class="data row0 col4" >1.22</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col5" class="data row0 col5" >3.44</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col6" class="data row0 col6" >4.56</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col7" class="data row0 col7" >6.33</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row0_col8" class="data row0 col8" >3.89</td>
#             </tr>
#             <tr>
#                         <th id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08level0_row1" class="row_heading level0 row1" >exp2</th>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col0" class="data row1 col0" >2.44</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col1" class="data row1 col1" >4.22</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col2" class="data row1 col2" >9</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col3" class="data row1 col3" >5.44</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col4" class="data row1 col4" >1.33</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col5" class="data row1 col5" >5.78</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col6" class="data row1 col6" >5.33</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col7" class="data row1 col7" >7.67</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row1_col8" class="data row1 col8" >3.78</td>
#             </tr>
#             <tr>
#                         <th id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08level0_row2" class="row_heading level0 row2" >exp3</th>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col1" class="data row2 col1" >3.78</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col2" class="data row2 col2" >8.89</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col3" class="data row2 col3" >4.78</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col4" class="data row2 col4" >1.11</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col5" class="data row2 col5" >4.33</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col6" class="data row2 col6" >5.22</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col7" class="data row2 col7" >8</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row2_col8" class="data row2 col8" >5.89</td>
#             </tr>
#             <tr>
#                         <th id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08level0_row3" class="row_heading level0 row3" >exp4</th>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col0" class="data row3 col0" >2.11</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col1" class="data row3 col1" >5.56</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col2" class="data row3 col2" >8.22</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col3" class="data row3 col3" >7.78</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col4" class="data row3 col4" >1.78</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col5" class="data row3 col5" >3.56</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col6" class="data row3 col6" >3.89</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col7" class="data row3 col7" >7.22</td>
#                         <td id="T_12e29d7a_3f4a_11ea_933d_f40f24125f08row3_col8" class="data row3 col8" >4.89</td>
#             </tr>
#     </tbody></table>

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.heatmap(summary, annot=True, linewidths=.5, ax=ax, cmap=sns.cm.rocket, vmin=-1)
u,l = ax.get_ylim()
ax.set_ylim(u+0.5, l-0.5)
ax.set_ylabel('')
ax.set_xlabel('')
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    tick.label.set_rotation(45)
    
for tick in ax.yaxis.get_major_ticks(): tick.label.set_fontsize(14)
plt.tight_layout()
fig.savefig(path/'heatmapRankARR.eps', dpi=400, format='eps')
