# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *

# %%
experiment=4
func='sphere'
path = Path(f'../../data/results/exp{experiment}/{func}')

# %%
D = 30
frequency = 1_000
max_times = 100
total_generations = max_times * frequency + 1000

# %%
if func=='sphere':
    if experiment==1 | experiment==2:
        ab = pd.read_csv(path/'dC_01.csv')['b'].values
        def fitness_func(indiv, b, t): return (indiv.data**2).sum()
        def constraint_func(indiv, b, t): return -b[t] + sum((1/np.sqrt(D))*indiv.data)

    elif experiment==3:
        ab=[]
        # experiment 3: dynamic fitness function (linear)
        def fitness_func(indiv, b, t): return ((indiv.data + 0.1*t)**2).sum()
        def constraint_func(indiv, b, t): return 0

    else:
        ab=pd.read_csv(path/'dC_01.csv')['b'].values
    # experiment 5: dynamic fitness function (x-sin(pi/2*t))^2 with random changes on peak of sin
        def fitness_func(indiv, b, t): return ((indiv.data-b[t]*np.sin(np.pi/2*t))**2).sum()
        def constraint_func(indiv, b, t): return 0
    
elif func=='rastrigin':
    if experiment==1 | experiment==2:
        ab = pd.read_csv(path/'dC_01.csv')['b'].values
        def fitness_func(indiv, b, t): return 10*D+((indiv.data**2)-10*np.cos(2*np.pi*indiv.data)).sum()
        def constraint_func(indiv, b, t): return -b[t] + sum((1/np.sqrt(D))*indiv.data)

    elif experiment==3:
        ab=[]
        # experiment 3: dynamic fitness function (linear)
        def fitness_func(indiv, b, t): return 10*D+(((indiv.data+0.1*t)**2)-10*np.cos(2*np.pi*indiv.data)).sum()
        def constraint_func(indiv, b, t): return 0

    else:
        ab=pd.read_csv(path/'dC_01.csv')['b'].values
    # experiment 5: dynamic fitness function (x-sin(pi/2*t))^2 with random changes on peak of sin
        def fitness_func(indiv, b, t): return 10*D+(((indiv.data-b[t]*np.sin(np.pi/2*t))**2)-10*np.cos(2*np.pi*indiv.data)).sum()
        def constraint_func(indiv, b, t): return 0

elif func=='rosenbrock':
    if experiment==1 | experiment==2:
        ab = pd.read_csv(path/'dC_01.csv')['b'].values
        def fitness_func(indiv, b, t): return ((100 * (indiv.data[1:] - indiv.data[:-1]**2)**2) + (1-indiv.data[:-1])**2).sum()
        def constraint_func(indiv, b, t): return -b[t] + sum((1/np.sqrt(D))*indiv.data)

    elif experiment==3:
        ab=[]
        # experiment 3: dynamic fitness function (linear)
        def fitness_func(indiv, b, t): return (100 * (((indiv.data[1:]+0.1*t) - (indiv.data[:-1]+0.1*t)**2)**2) + (1-indiv.data[:-1]-0.1*t)**2).sum()
        def constraint_func(indiv, b, t): return 0

    else:
        ab=pd.read_csv(path/'dC_01.csv')['b'].values
    # experiment 5: dynamic fitness function (x-sin(pi/2*t))^2 with random changes on peak of sin
        def fitness_func(indiv, b, t): return (((100 * ((indiv.data[1:]-b[t]*np.sin(np.pi/2*t)) - (indiv.data[:-1]-b[t]*np.sin(np.pi/2*t))**2)**2) + (1-indiv.data[:-1]+b[t]*np.sin(np.pi/2*t))**2)).sum()
        def constraint_func(indiv, b, t): return 0

# %%
class DebuggerCallback(Callback):
    def on_gen_begin(self, time, best, **kwargs):
        print(f'time {time} - best: fitness={best.fitness_value} is_feasible={best.is_feasible}')
        
    def on_gen_end(self, time, best, **kwargs):
        print(f'time {time} - best: fitness={best.fitness_value} is_feasible={best.is_feasible}')

# %%
population = Population.new_random(dimension=D)

opt = Optimization(population, fitness_func, constraint_func, fitness_params=ab, constraint_params=[ab],
                   max_times=max_times, frequency=frequency, callbacks=[OnChangeRestartPopulation,DebuggerCallback],
                   metrics=[AbsoluteRecoverRate])
opt.state_dict
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-2a09b6255fa1> in <module>
#       3 opt = Optimization(population, fitness_func, constraint_func, fitness_params=ab, constraint_params=[ab],
#       4                    max_times=max_times, frequency=frequency, callbacks=[OnChangeRestartPopulation,DebuggerCallback],
# ----> 5                    metrics=[AbsoluteRecoverRate])
#       6 opt.state_dict
#
# <string> in __init__(self, population, get_fitness, get_constraints, fitness_params, constraint_params, max_times, frequency, CR, beta_min, beta_max, max_evals, time_change_detect, time_change_pcts, callbacks, metrics, optimal_fitness_values, optimal_sum_constraints)
#
# ~/DENN/denn/optimization.py in __post_init__(self)
#     162             self.time_change_checks = [int(self.population.n*e) for e in self.time_change_pcts]
#     163
# --> 164         self.callbacks = [Recorder(self)] + [e(self) for e in listify(self.callbacks)] + [e(self) for e in get_metrics(self.metrics)]
#     165         self.cb_handler = CallbackHandler(self, self.callbacks)
#     166         self.metrics = [e for e in self.callbacks if isinstance(e, Metric)]
#
# ~/DENN/denn/optimization.py in <listcomp>(.0)
#     162             self.time_change_checks = [int(self.population.n*e) for e in self.time_change_pcts]
#     163
# --> 164         self.callbacks = [Recorder(self)] + [e(self) for e in listify(self.callbacks)] + [e(self) for e in get_metrics(self.metrics)]
#     165         self.cb_handler = CallbackHandler(self, self.callbacks)
#     166         self.metrics = [e for e in self.callbacks if isinstance(e, Metric)]
#
# ~/DENN/denn/metrics.py in __init__(self, optim)
#      91         '''
#      92         super().__init__(optim)
# ---> 93         assert optim.optimal_fitness_values is not None, 'no optimal fitness values were given.'
#      94         self.time_values = []
#      95         self.metrics = 0.0
#
# AssertionError: no optimal fitness values were given.

# %%
opt.run(total_generations, update_each=1)
# Out:
# Total time: 00:31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/denn/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~/anaconda3/envs/denn/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/envs/denn/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/envs/denn/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-091226a1c00a> in <module>
# ----> 1 opt.run(total_generations, update_each=1)
#
# ~/DENN/denn/optimization.py in run(self, generations, show_graph, update_each, show_report, silent)
#     295             for _ in pbar:
#     296                 bar = range(generations) if silent else progress_bar(range(generations), parent=pbar)
# --> 297                 for gen in bar: self.run_one_gen()
#     298
#     299         except CancelRunException as exception: self.cb_handler.on_cancel_run(exception)
#
# ~/DENN/denn/optimization.py in run_one_gen(self)
#     285
#     286         except CancelGenException as exception: self.cb_handler.on_cancel_gen(exception)
# --> 287         finally: self.cb_handler.on_gen_end()
#     288
#     289     def run(self, generations:int, show_graph:bool=True, update_each:int=10, show_report:bool=True, silent:bool=False)->None:
#
# ~/DENN/denn/callbacks.py in on_gen_end(self, **kwargs)
#     233
#     234     def on_gen_end(self, **kwargs:Any)->None:
# --> 235         self('gen_end')
#     236         self.state_dict['gen'] += 1
#     237
#
# ~/DENN/denn/callbacks.py in __call__(self, cb_name, **kwargs)
#      62
#      63     def __call__(self, cb_name:str, **kwargs:Any)->None:
# ---> 64         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#      65
#      66     def on_run_begin(self, generations:int, pbar:PBar, max_evals:Optional[int], max_times:Optional[int],
#
# ~/DENN/denn/callbacks.py in _call_and_update(self, cb, cb_name, **kwargs)
#      55     def _call_and_update(self, cb:Callback, cb_name:str, **kwargs:Any)->None:
#      56         "Call `cb_name` on `cb` and update the inner state."
# ---> 57         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#      58         for k,v in new.items():
#      59             if k not in self.state_dict:
#
# <ipython-input-13-f22aff6bb85c> in on_gen_end(self, time, best, **kwargs)
#       5     def on_gen_end(self, time, best, **kwargs):
#       6         print(f'time {time} - best: fitness={best.fitness_value} is_feasible={best.is_feasible}')
# ----> 7         input()
#
# ~/anaconda3/envs/denn/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# ~/anaconda3/envs/denn/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:

# %%
opt.recorder.plot();

# %%
df = pd.DataFrame({'fitness':opt.recorder.best_times_fitness, 'sum_constraints':opt.recorder.best_times_constraints})
df.head()
# Out:
#         fitness  sum_constraints
# 0     29.081381                0
# 1   4016.515196                0
# 2     34.569805                0
# 3  54045.266976                0
# 4     31.529437                0

# %%
path.mkdir(parents=True, exist_ok=True)
df.to_csv(path/'best_known.csv', index=False)
