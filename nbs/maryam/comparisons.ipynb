# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *
path = Path('../../data/results/exp1/sphere')

# %%
bestPython=pd.read_csv(path/'best_known.csv')[['fitness']]
bestJava=pd.read_csv(path/'Best_Know1Fxs.csv', header=None)

# %%
df = pd.concat([bestJava.T[:100], bestPython], axis=1)
df.columns = ['java', 'python']

# %%
plt.plot(df.java - df.python)
