# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from denn import *
path = Path('../../data/results/exp1/compare')

# %%
best1=pd.read_csv(path/'best_known.csv')[['fitness']]
best2=pd.read_csv(path/'best_known2.csv')[['fitness']]
plt.plot(best2)

# %%
df = pd.concat([best1, best2], axis=1)
df.columns = ['medium', 'large']

# %%
df
# Out:
#           medium         large
# 0   5.365584e-77  7.695753e-76
# 1   2.566961e+02  2.567546e+02
# 2   6.360070e+02  6.360572e+02
# 3   7.500000e+02  7.500000e+02
# 4   7.500000e+02  7.500000e+02
# 5   7.500000e+02  7.500000e+02
# 6   7.441816e+01  7.441548e+01
# 7   1.785022e+02  1.784793e+02
# 8   1.075701e-76  1.577688e-75
# 9   1.619161e-76  1.233914e-76
# 10  9.984009e-01  9.983738e-01
# 11  5.899862e-77  1.030206e-76
# 12  3.547900e-77  2.007632e-76
# 13  3.245110e+00  3.244739e+00
# 14  2.055390e+02  2.055648e+02
# 15  2.453592e+00  2.453475e+00
# 16  1.469651e+00  1.469476e+00
# 17  1.114565e+02  1.114865e+02
# 18  5.825088e+00  5.824479e+00
# 19  1.602432e-75  1.007713e-75
# 20  2.543006e+01  2.543307e+01
# 21  9.711757e-76  1.150863e-77
# 22  1.029560e-78  1.533672e-76
# 23  1.561596e-75  4.335049e-77
# 24  8.844102e-76  2.492791e-76
# 25  3.795353e-77  5.055631e-77
# 26  3.444870e-77  1.787113e-76
# 27  3.596382e-76  1.043832e-76
# 28  2.481715e-76  2.981406e-77
# ...
